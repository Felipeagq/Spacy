# %%
#instalamos la libreria
#!pip3 install spacy

# %%
# instalamos la dependencia de ingles
# !python3 -m spacy download en_core_web_sm
# Out:
# 2021-03-29 09:48:35.142091: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-03-29 09:48:35.142113: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# Requirement already satisfied: en-core-web-sm==3.0.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.0.0/en_core_web_sm-3.0.0-py3-none-any.whl#egg=en_core_web_sm==3.0.0 in /home/lyaelectronic/.local/lib/python3.8/site-packages (3.0.0)
# Requirement already satisfied: spacy<3.1.0,>=3.0.0 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from en-core-web-sm==3.0.0) (3.0.3)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.7.4)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/lib/python3/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.22.0)
# Requirement already satisfied: thinc<8.1.0,>=8.0.0 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (8.0.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.0 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (4.59.0)
# Requirement already satisfied: packaging>=20.0 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (20.9)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.3.2)
# Requirement already satisfied: pathy in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.4.0)
# Requirement already satisfied: numpy>=1.15.0 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.19.5)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (45.2.0)
# Requirement already satisfied: pydantic<1.8.0,>=1.7.1 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.7.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.0.5)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.1 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.0.1)
# Requirement already satisfied: jinja2 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.11.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.0 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.0.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.8.2)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from packaging>=20.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.4.7)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from typer<0.4.0,>=0.3.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (7.1.2)
# Requirement already satisfied: smart-open<4.0.0,>=2.2.0 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from pathy->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/lib/python3/dist-packages (from jinja2->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.1.0)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# instalamos la dependencia de español
# !python3 -m spacy download es_core_news_sm
# Out:
# 2021-03-29 09:49:01.829058: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-03-29 09:49:01.829082: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# Requirement already satisfied: es-core-news-sm==3.0.0 from https://github.com/explosion/spacy-models/releases/download/es_core_news_sm-3.0.0/es_core_news_sm-3.0.0-py3-none-any.whl#egg=es_core_news_sm==3.0.0 in /home/lyaelectronic/.local/lib/python3.8/site-packages (3.0.0)
# Requirement already satisfied: spacy<3.1.0,>=3.0.0 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from es-core-news-sm==3.0.0) (3.0.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (4.59.0)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (0.7.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (1.0.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (0.8.2)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (0.3.2)
# Requirement already satisfied: pathy in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (0.4.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (2.0.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (3.0.5)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.1 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (2.0.1)
# Requirement already satisfied: thinc<8.1.0,>=8.0.0 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (8.0.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.0 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (2.4.0)
# Requirement already satisfied: numpy>=1.15.0 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (1.19.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/lib/python3/dist-packages (from spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (2.22.0)
# Requirement already satisfied: pydantic<1.8.0,>=1.7.1 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (1.7.3)
# Requirement already satisfied: jinja2 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (2.11.3)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (45.2.0)
# Requirement already satisfied: packaging>=20.0 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (20.9)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.0 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (3.0.1)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from typer<0.4.0,>=0.3.0->spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (7.1.2)
# Requirement already satisfied: smart-open<4.0.0,>=2.2.0 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from pathy->spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (3.0.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/lib/python3/dist-packages (from jinja2->spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (1.1.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from packaging>=20.0->spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (2.4.7)
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_sm')

# %%
# importamos la libreria
import spacy
