# %% [markdown]
# # Introduccion --> English

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
text = 'LA Electronics is looking for new employees B-quilla C.O. to hire them for $ 1 Million and be able to expand the number of projects they can work on'

# %%
nlp = spacy.load('en_core_web_sm')

# %%
# lo hacemos un objeto de spacy
doc = nlp(text)

# %%
for token in doc:
    print(f'{token.text:13} : {token.pos_}')
# Out:
# LA            : PROPN
# Electronics   : PROPN
# is            : AUX
# looking       : VERB
# for           : ADP
# new           : ADJ
# employees     : NOUN
# B             : NOUN
# -             : PUNCT
# quilla        : NOUN
# C.O.          : PROPN
# to            : PART
# hire          : VERB
# them          : PRON
# for           : ADP
# $             : SYM
# 1             : NUM
# Million       : NUM
# and           : CCONJ
# be            : VERB
# able          : ADJ
# to            : PART
# expand        : VERB
# the           : DET
# number        : NOUN
# of            : ADP
# projects      : NOUN
# they          : PRON
# can           : AUX
# work          : VERB
# on            : ADP
