# %%
# !pip3 install nltk
import nltk
nltk.download()
# Out:
# Requirement already satisfied: nltk in /home/lyaelectronic/.local/lib/python3.8/site-packages (3.5)
# Requirement already satisfied: joblib in /home/lyaelectronic/.local/lib/python3.8/site-packages (from nltk) (1.0.1)
# Requirement already satisfied: click in /home/lyaelectronic/.local/lib/python3.8/site-packages (from nltk) (7.1.2)
# Requirement already satisfied: regex in /home/lyaelectronic/.local/lib/python3.8/site-packages (from nltk) (2020.11.13)
# Requirement already satisfied: tqdm in /home/lyaelectronic/.local/lib/python3.8/site-packages (from nltk) (4.59.0)
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
# !pip3 install spacy && python3 -m spacy download es
import spacy
spacy.load("es_core_news_sm")
# Out:
# Requirement already satisfied: spacy in /home/lyaelectronic/.local/lib/python3.8/site-packages (3.0.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.0 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy) (3.0.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy) (0.3.2)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from spacy) (45.2.0)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy) (0.7.4)
# Requirement already satisfied: srsly<3.0.0,>=2.4.0 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy) (2.4.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.1 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy) (2.0.1)
# Requirement already satisfied: numpy>=1.15.0 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy) (1.19.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy) (2.0.5)
# Requirement already satisfied: jinja2 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy) (2.11.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy) (3.0.5)
# Requirement already satisfied: pathy in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy) (0.4.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/lib/python3/dist-packages (from spacy) (2.22.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy) (4.59.0)
# Requirement already satisfied: thinc<8.1.0,>=8.0.0 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy) (8.0.2)
# Requirement already satisfied: pydantic<1.8.0,>=1.7.1 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy) (1.7.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy) (0.8.2)
# Requirement already satisfied: packaging>=20.0 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy) (20.9)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from typer<0.4.0,>=0.3.0->spacy) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/lib/python3/dist-packages (from jinja2->spacy) (1.1.0)
# Requirement already satisfied: smart-open<4.0.0,>=2.2.0 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from pathy->spacy) (3.0.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from packaging>=20.0->spacy) (2.4.7)
# 2021-03-29 07:49:58.143166: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-03-29 07:49:58.143194: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# ⚠ As of spaCy v3.0, shortcuts like 'es' are deprecated. Pleaseuse the
# full pipeline package name 'es_core_news_sm' instead.
# Requirement already satisfied: es-core-news-sm==3.0.0 from https://github.com/explosion/spacy-models/releases/download/es_core_news_sm-3.0.0/es_core_news_sm-3.0.0-py3-none-any.whl#egg=es_core_news_sm==3.0.0 in /home/lyaelectronic/.local/lib/python3.8/site-packages (3.0.0)
# Requirement already satisfied: spacy<3.1.0,>=3.0.0 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from es-core-news-sm==3.0.0) (3.0.3)
# Requirement already satisfied: packaging>=20.0 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (20.9)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.1 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (2.0.1)
# Requirement already satisfied: numpy>=1.15.0 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (1.19.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.0 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (3.0.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (4.59.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (2.0.5)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (0.7.4)
# Requirement already satisfied: thinc<8.1.0,>=8.0.0 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (8.0.2)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (0.3.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/lib/python3/dist-packages (from spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (2.22.0)
# Requirement already satisfied: pathy in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (0.4.0)
# Requirement already satisfied: pydantic<1.8.0,>=1.7.1 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (1.7.3)
# Requirement already satisfied: jinja2 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (2.11.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.0 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (2.4.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (1.0.5)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (45.2.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (3.0.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (0.8.2)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from packaging>=20.0->spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (2.4.7)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from typer<0.4.0,>=0.3.0->spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (7.1.2)
# Requirement already satisfied: smart-open<4.0.0,>=2.2.0 in /home/lyaelectronic/.local/lib/python3.8/site-packages (from pathy->spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (3.0.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/lib/python3/dist-packages (from jinja2->spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (1.1.0)
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_sm')

# %%
# !pip3 install textblob

# %%
# !pip3 install CoreNLP

# %% [markdown]
# # Extracting Data

# %%
"""Recipe 1. Text data collection using APIs
Recipe 2. Reading PDF file in Python
Recipe 3. Reading word document
Recipe 4. Reading JSON object
Recipe 5. Reading HTML page and HTML parsing
Recipe 6. Regular expressions
Recipe 7. String handling
Recipe 8. Web scraping"""

# %%
# EXTRAER TEXTO DE PDF

# !pip install PyPDF2
import PyPDF2
from PyPDF2 import PdfFileReader
#Creating a pdf file object
pdf = open("file.pdf","rb")
#creating pdf reader object
pdf_reader = PyPDF2.PdfFileReader(pdf)
#checking number of pages in a pdf file
print(pdf_reader.numPages)
#creating a page object
page = pdf_reader.getPage(0)
#finally extracting text from the page
print(page.extractText())
#closing the pdf file
pdf.close()

# %%
# EXTRAER TEXTO DE WORD FILES

#Install docx
# !pip install docx
#Import library
from docx import Document
#Creating a word file object
doc = open("file.docx","rb")
#creating word reader object
document = docx.Document(doc)
# create
variable
create a
document
an empty string and call this document. This document
store each paragraph in the Word document.We then
for loop that goes through each paragraph in the Word
and appends the paragraph.
docu=""
for para in document.paragraphs:
       docu += para.text
#to see the output call docu
print(docu)

# %%
# EXTRAER DATA DE UN HTML

# !pip install bs4
import urllib.request as urllib2
from bs4 import BeautifulSoup
response = urllib2.urlopen('https://en.wikipedia.org/wiki/
Natural_language_processing')
html_doc = response.read()
#Parsing
soup = BeautifulSoup(html_doc, 'html.parser')
# Formating the parsed html file
strhtm = soup.prettify()
# Print few lines
print (strhtm[:1000])
print(soup.title)
print(soup.title.string)
print(soup.a.string)
print(soup.b.string)
# Extracting all instances of a particular tag
for x in soup.find_all('a'): print(x.string)
for x in soup.find_all('p'): print(x.text)

# %%
# Parsing Text Using Regular Expressions
"""
re.I: This flag is used for ignoring casing.
• re.L: This flag is used to find a local dependent.
• re.M: This flag is useful if you want to find patterns
throughout multiple lines.
• re.S: This flag is used to find dot matches.
• re.U: This flag is used to work for unicode data.
• re.X: This flag is used for writing regex in a more
readable format.
Regular expressions’ functionality:
•
Find the single occurrence of character a and b:
Regex: [ab]
•
Find characters except for a and b:
Regex: [^ab]
16Chapter 1
•
Extracting the Data
Find the character range of a to z:
Regex: [a-z]
•
Find a range except to z:
Regex: [^a-z]
•
Find all the characters a to z as well as A to Z:
Regex: [a-zA-Z]
•
Any single character:
Regex:
•
Any whitespace character:
Regex: \s
•
Any non-whitespace character:
Regex: \S
•
Any digit:
Regex: \d
•
Any non-digit:
Regex: \D
•
Any non-words:
Regex: \W
•
Any words:
Regex: \w
17Chapter 1
•
Extracting the Data
Either match a or b:
Regex: (a|b)
•
The occurrence of a is either zero or one:
•
Matches zero or one occurrence but not more than
one occurrence
Regex: a? ; ?
•
The occurrence of a is zero times or more than that:
Regex: a* ; * matches zero or more than that
•
The occurrence of a is one time or more than that:
Regex: a+ ; + matches occurrences one or more that
one time
•
Exactly match three occurrences of a:
Regex: a{3}
•
Match simultaneous occurrences of a with 3 or more
than 3:
Regex: a{3,}
•
Match simultaneous occurrences of a between 3 to 6:
Regex: a{3,6}
•
Starting of the string:
Regex: ^
•
Ending of the string:
Regex: $
18Chapter 1
•
Extracting the Data
Match word boundary:
Regex: \b
•
Non-word boundary:
Regex: \B
re.match() and re.search() functions are used to find the patterns
and then can be processed according to the requirements of the application.
Let’s look at the differences between re.match() and re.search():

• re.match(): This checks for a match of the string only
at the beginning of the string. So, if it finds the pattern
at the beginning of the input string, then it returns the
matched pattern; otherwise; it returns a noun.

• re.search(): This checks for a match of the string
anywhere in the string. It finds all the occurrences of
the pattern in the given input string or data.s between re.match() and re.search():

• re.match(): This checks for a match of the string only
at the beginning of the string. So, if it finds the pattern
at the beginning of the input string, then it returns the
matched pattern; otherwise; it returns a noun.

• re.search(): This checks for a match of the string
anywhere in the string. It finds all the occurrences of
the pattern in the given input string or data."""

# Import library
import re
#run the split query
re.split('\s+','I like this book.')
# Out:
# ['I', 'like', 'this', 'book.']

# %%
# Scraping Text from the Web

# !pip install bs4
# !pip install requests
from bs4 import BeautifulSoup
import requests
import pandas as pd
from pandas import Series, DataFrame
from ipywidgets import FloatProgress
from time import sleep
from IPython.display import display
import re
import pickle
url = 'http://www.imdb.com/chart/top?ref_=nv_mv_250_6'
result = requests.get(url)
c = result.content
soup = BeautifulSoup(c,"lxml")
